# %% [markdown]
# # Exploratory Data Analysis on the Dataset:

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from data.auto_mpg import get_data

# %%
df = get_data()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_data()
#
# File d:\Multimedia\rebuild\opensource\example\notebook\..\data\auto_mpg.py:5, in get_data()
#       4 def get_data():
# ----> 5     conn = get_connection()
#       7     df = pd.read_sql("SELECT * FROM auto_mpg",conn)
#       9     conn.close()
#
# File d:\Multimedia\rebuild\opensource\example\notebook\..\data\db.py:8, in get_connection()
#       7 def get_connection():
# ----> 8     conn = psycopg.connect(
#       9         host = os.getenv("DB_HOST"),
#      10         port=os.getenv("DB_PORT"),
#      11         dbname=os.getenv("DB_NAME"),
#      12         user=os.getenv("DB_USER"),
#      13         password=os.getenv("DB_PASSWORD")
#      14     )
#      15     return conn
#
# File d:\Multimedia\rebuild\opensource\example\.venv\Lib\site-packages\psycopg\connection.py:122, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     120 last_ex = conn_errors[-1][0]
#     121 if len(conn_errors) == 1:
# --> 122     raise last_ex.with_traceback(None)
#     124 # Create a new exception with the same type as the last one, containing
#     125 # all attempt errors while preserving backward compatibility.
#     126 lines = [str(last_ex)]
#
# OperationalError: connection failed: connection to server at "localhost" (::1), port 5432 failed: fe_sendauth: no password supplied
